# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Me\Downloads/Training Data.csv") # file reading

print('Data_Shape:',df.shape)
# Out:
# Data_Shape: (965, 56)

# %%
#client id
#pubclient id
#clickIp
#clmbuser id 
#impr id
#site id
#goal id
#City id / State id / CountryDim id
#browser id
#adslot id
#crtd
#itmclmb id
#ispDimId
#devTypeDimId
#osVerDimId

# %%
b = df

# %%
a = df.drop(['conversiontime_cr','adslotdimid_cr', 'algo_cr', 'audiences_cr', 'clickbid_cr', 'geodimid_cr','itemcolumbiaid_cr', 'itemid_cr', 'position_cr','refurl_cr', 'templateid_cr','adLogType_cr', 'v_cr', 'allAudiences_cr',
       'pricingtype_cr', 'osId_cr','modelDimId_cr', 'lookUpFrom_cr', 'connTypeDimId_cr','goalTypeId_cr', 'conversionDurationInMillis_cr',
       'impressionTimeInMillis_cr', 'clickTimeInMillis_cr','uuidSource_cr', 'geoGrpDimId_cr', 'stateGrpDimId_cr','uvh_cr', 'uv_cr', 'platformId_cr', 'sdkVersion_cr', 'usrClusterId_cr',
       'cityGrpDimId_cr', 'siteClusterIds_cr', 'refClusterId_cr', 'paid_cr',
       'spend_cr', 'attributionType_cr', 'conversionid_cr', 'optimize_on_cr',
       'bundleId_cr',],axis =1)

# %%
df.columns
# Out:
# Index(['clientid_cr', 'clmbuserid_cr', 'conversiontime_cr', 'imprid_cr',
#        'adslotdimid_cr', 'algo_cr', 'audiences_cr', 'clickbid_cr',
#        'geodimid_cr', 'ip_cr', 'itemcolumbiaid_cr', 'itemid_cr', 'position_cr',
#        'pubclientid_cr', 'refurl_cr', 'siteId_cr', 'templateid_cr',
#        'goalid_cr', 'time_cr', 'adLogType_cr', 'v_cr', 'allAudiences_cr',
#        'pricingtype_cr', 'osId_cr', 'browserId_cr', 'cityId_cr', 'stateId_cr',
#        'modelDimId_cr', 'lookUpFrom_cr', 'connTypeDimId_cr', 'ispDimId_cr',
#        'countryDimId_cr', 'goalTypeId_cr', 'conversionDurationInMillis_cr',
#        'impressionTimeInMillis_cr', 'clickTimeInMillis_cr', 'osVerDimId_cr',
#        'uuidSource_cr', 'geoGrpDimId_cr', 'stateGrpDimId_cr', 'deviceId_cr',
#        'uvh_cr', 'uv_cr', 'platformId_cr', 'sdkVersion_cr', 'usrClusterId_cr',
#        'cityGrpDimId_cr', 'siteClusterIds_cr', 'refClusterId_cr', 'paid_cr',
# ...

# %%
a.shape
# Out:
# (965, 16)

# %%
a.head()
# Out:
#    clientid_cr                               clmbuserid_cr  \
# 0        75694  31629cd0-0b34-460f-aa61-80c3234e1225-1sjfw
# 1        75694  4c98f114-c34c-48f4-84d6-50fc8e9b6d65-10wgg
# 2        75694  cd92087a-54b0-4911-bc3d-1144a3c2babd-1sjlg
# 3        75694  f79f3de7-5edb-4319-9549-117f47996066-10wrk
# 4        30431  01fd1a8a-c3f8-4b57-94ff-66318d0f63c7-1sjts
#
#                                     imprid_cr            ip_cr  \
# 0  01649076-c77f-4d70-afc8-213535427147-1sjd4  XXX.XXX.XXX.XXX
# 1  f84d83b9-b757-4f97-9813-34f8dcc57cc5-1sjfw  XXX.XXX.XXX.XXX
# 2  061edef6-3d9d-408b-884a-ad840e6930ce-10o78  XXX.XXX.XXX.XXX
# 3  0a937239-9091-4bb7-b26b-37d4bb29e50b-10oa0  XXX.XXX.XXX.XXX
# 4  0d46d0d4-8fc6-4d95-aaa1-406354a8400c-1sjo8  XXX.XXX.XXX.XXX
#
#    pubclientid_cr  siteId_cr  goalid_cr       time_cr  browserId_cr  \
# 0            2320         34       6384  1.620000e+12      129639.0
# 1           15240        178       6384  1.620000e+12      129639.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = a.corr()

f, ax = plt.subplots(figsize=(30, 15))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(17, 7))
a.isnull().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
a = a.fillna(0)

# %%
plt.figure(figsize=(17, 7))
a.isnull().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
corrmat = a.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(30,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
X = a.iloc[:,0:15]  #independent columns
y = a.iloc[:,-1]    #target column i.e

# %%
X
# Out:
#      clientid_cr                               clmbuserid_cr  \
# 0          75694  31629cd0-0b34-460f-aa61-80c3234e1225-1sjfw
# 1          75694  4c98f114-c34c-48f4-84d6-50fc8e9b6d65-10wgg
# 2          75694  cd92087a-54b0-4911-bc3d-1144a3c2babd-1sjlg
# 3          75694  f79f3de7-5edb-4319-9549-117f47996066-10wrk
# 4          30431  01fd1a8a-c3f8-4b57-94ff-66318d0f63c7-1sjts
# ..           ...                                         ...
# 960         2139        41d7dab3-0ab7-4039-a936-2ceab9dbcbf7
# 961        70491        39511cf3-0358-4ae9-9fec-fe3a74e98a13
# 962        85572  e5d4037f-ec67-4d7b-8d83-9012ee7d64b9-1sjac
# 963        75694  c7491247-f203-48df-b08d-d25d0d873e20-1sjwk
# 964        75694   20dcb941-42eb-4f0c-8f96-7afe12146264-h0k8
#
#                                       imprid_cr            ip_cr  \
# 0    01649076-c77f-4d70-afc8-213535427147-1sjd4  XXX.XXX.XXX.XXX
# 1    f84d83b9-b757-4f97-9813-34f8dcc57cc5-1sjfw  XXX.XXX.XXX.XXX
# ...

# %%
y
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# Name: conversion_fraud, Length: 965, dtype: bool

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression
# Sequential Forward Selection(sfs)
sfs = SFS(LinearRegression(),
          k_features=12,
          forward=True,
          floating=False,
          scoring = 'r2',
          cv = 0)

# %%
sfs.fit(X, y)
sfs.k_feature_names_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-bdf227e9dbbc> in <module>
# ----> 1 sfs.fit(X, y)
#       2 sfs.k_feature_names_
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py in fit(self, X, y, custom_feature_names, groups, **fit_params)
#     437                         y=y,
#     438                         groups=groups,
# --> 439                         **fit_params
#     440                     )
#     441                 else:
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py in _inclusion(self, orig_set, subset, X, y, ignore_feature, groups, **fit_params)
#     606                              tuple(subset | {feature}),
#     607                              groups=groups, **fit_params)
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for column in a.columns:
    if a[column].dtype == type(object):
        a[column] = le.fit_transform(a[column])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\_encode.py in _unique_python(values, return_inverse)
#     131
# --> 132         uniques = sorted(uniques_set)
#     133         uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-da582e9cf34a> in <module>
#       3 for column in a.columns:
#       4     if a[column].dtype == type(object):
# ----> 5         a[column] = le.fit_transform(a[column])
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\_label.py in fit_transform(self, y)
#     115         """
# ...

# %%
a['clmbuserid_cr'] = le.fit_transform(a['clmbuserid_cr'].astype(str))

# %%
a['imprid_cr'] = le.fit_transform(a['imprid_cr'].astype(str))

# %%
sfs.fit(X, y)
sfs.k_feature_names_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-2f6d75ef8b0c> in <module>
# ----> 1 sfs.fit(X, y)
#       2 sfs.k_feature_names_
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py in fit(self, X, y, custom_feature_names, groups, **fit_params)
#     437                         y=y,
#     438                         groups=groups,
# --> 439                         **fit_params
#     440                     )
#     441                 else:
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\mlxtend\feature_selection\sequential_feature_selector.py in _inclusion(self, orig_set, subset, X, y, ignore_feature, groups, **fit_params)
#     606                              tuple(subset | {feature}),
#     607                              groups=groups, **fit_params)
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for column in a.columns:
    if a[column].dtype == type(object):
        a[column] = le.fit_transform(a[column])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\_encode.py in _unique_python(values, return_inverse)
#     131
# --> 132         uniques = sorted(uniques_set)
#     133         uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-da582e9cf34a> in <module>
#       3 for column in a.columns:
#       4     if a[column].dtype == type(object):
# ----> 5         a[column] = le.fit_transform(a[column])
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\_label.py in fit_transform(self, y)
#     115         """
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 965 entries, 0 to 964
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   clientid_cr       965 non-null    int64
#  1   clmbuserid_cr     965 non-null    int32
#  2   imprid_cr         965 non-null    int32
#  3   ip_cr             965 non-null    object
#  4   pubclientid_cr    965 non-null    int64
#  5   siteId_cr         965 non-null    int64
#  6   goalid_cr         965 non-null    int64
#  7   time_cr           965 non-null    float64
#  8   browserId_cr      965 non-null    float64
#  9   cityId_cr         965 non-null    float64
#  10  stateId_cr        965 non-null    float64
#  11  ispDimId_cr       965 non-null    float64
#  12  countryDimId_cr   965 non-null    float64
#  13  osVerDimId_cr     965 non-null    float64
#  14  deviceId_cr       965 non-null    float64
#  15  conversion_fraud  965 non-null    bool
# ...
